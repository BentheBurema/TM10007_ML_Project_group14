# %% [markdown]
# <a href="https://colab.research.google.com/github/BentheBurema/TM10007_ML_Project_group14/blob/main/checking_on_zeros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TM10007 Assignment Group 14 Dataset 2

# %% [markdown]
# ## Importing libraries

# %%
# Basic packages
import numpy as np
import pandas as pd
import seaborn
import matplotlib.pyplot as plt

# Inspecting dataset
from scipy.stats import kstest

# Splitting dataset
from sklearn import model_selection

# Pre-processing
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest, f_classif, VarianceThreshold, RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV, train_test_split, cross_val_score
from scipy.stats import linregress, uniform, skew, kurtosis, norm

# Classifiers
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn import tree, metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import learning_curve
from sklearn.metrics import make_scorer, fbeta_score, classification_report, auc, roc_curve, precision_recall_fscore_support, confusion_matrix, ConfusionMatrixDisplay, roc_auc_score
from tabulate import tabulate

# %%
# Run this to use from colab environment
# !pip install -q --upgrade git+https://github.com/jveenland/tm10007_ml.git
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for ktml (setup.py) ... done

# %% [markdown]
# ## Data loading

# %%
# Data loading functions.
# !git clone https://github.com/BentheBurema/TM10007_ML_Project_group14.git # ik snap niet waarom we dit doen? timo
from worcliver.load_data import load_data
data = load_data()
# Out:
# Cloning into 'TM10007_ML_Project_group14'...
# remote: Enumerating objects: 217, done.
# remote: Counting objects: 100% (217/217), done.
# remote: Compressing objects: 100% (123/123), done.
# remote: Total 217 (delta 103), reused 194 (delta 92), pack-reused 0
# Receiving objects: 100% (217/217), 78.36 MiB | 31.18 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %% [markdown]
# ## Inspecting data

# %%
# Finding the number of missing and incorrect values
print(f"Number of None types: {data.isnull().sum().sum()}")     # Count number of None types
print(f"Number of NaN values: {data.isna().sum().sum()}")       # Count number of NaN values
print(f'The number of samples: {len(data.index)}')              # print number of samples, features and feature names
print(f'The number of features: {len(data.columns)}')

# Check if the dataset is balanced
malignant = (data['label'] == 'malignant').sum()
print(f'The percentage of tumors that is malignant is {(malignant/len(data.index))*100}')

# Check if the data is normally distributed
Y = data['label']
X = data.drop('label', axis=1)

p_values = {}
for key,values in X.items():

  #perform Kolmogorov-Smirnov test on the values and store the p_values
  _, p_value = kstest(values, 'norm')
  # Store the p-value in the dictionary
  p_values[key] = p_value

# If p<0.05 the feature is not normally distributed, if p>0.05 the feature is normally distributed
count_less_than_005 = sum(p_value < 0.05 for p_value in p_values.values())
count_greater_than_005 = sum(p_value > 0.05 for p_value in p_values.values())

print(f"Amount of featuers not normally distributed: {count_less_than_005}")
print(f"Amount of features normally distributed: {count_greater_than_005}")
# Out:
# Number of None types: 0
# Number of NaN values: 0
# The number of samples: 186
# The number of features: 494
# The percentage of tumors that is malignant is 50.53763440860215
# Amount of featuers not normally distributed: 493
# Amount of features normally distributed: 0

# %% [markdown]
# ## Splitting dataset in training set and test set

# %%
Y = data['label']
X = data.drop('label', axis=1)

# Split the dataset in training and test part
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X,Y,test_size=0.2,random_state=0,stratify=Y)

# Check if this is executed correctly
print("Amount samples in X_train (X_train):", X_train.shape[0])
print("Amount samples in X_test  (X_test):", X_test.shape[0])
print("Amount samples in Y_train (Y_train):", Y_train.shape[0])
print("Amount samples in Y_test (Y_test):", Y_test.shape[0])

display(X_train.head())

# Transform datasets to dataframes
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)
# Out:
# Amount samples in X_train (X_train): 148
# Amount samples in X_test  (X_test): 38
# Amount samples in Y_train (Y_train): 148
# Amount samples in Y_test (Y_test): 38
#              PREDICT_original_sf_compactness_avg_2.5D  \
# ID
# Liver-149_0                                  0.824583
# Liver-132_0                                  0.801146
# Liver-018_0                                  0.784347
# Liver-135_0                                  0.762971
# Liver-015_0                                  0.836579
#
#              PREDICT_original_sf_compactness_std_2.5D  \
# ID
# Liver-149_0                                  0.055989
# Liver-132_0                                  0.092439
# Liver-018_0                                  0.051682
# Liver-135_0                                  0.071214
# Liver-015_0                                  0.075738
#
#              PREDICT_original_sf_rad_dist_avg_2.5D  \
# ID
# Liver-149_0                              30.099345
# Liver-132_0                              62.217271
# Liver-018_0                              29.057589
# Liver-135_0                              39.719594
# Liver-015_0                              61.507831
#
#              PREDICT_original_sf_rad_dist_std_2.5D  \
# ID
# Liver-149_0                               4.415992
# Liver-132_0                               5.375470
# Liver-018_0                               5.423131
# Liver-135_0                               6.220513
# Liver-015_0                               7.303462
#
#              PREDICT_original_sf_roughness_avg_2.5D  \
# ID
# Liver-149_0                                3.661071
# Liver-132_0                                6.822246
# Liver-018_0                                8.776120
# Liver-135_0                                8.349609
# Liver-015_0                               11.104662
#
#              PREDICT_original_sf_roughness_std_2.5D  \
# ID
# Liver-149_0                                1.861613
# Liver-132_0                                2.509137
# Liver-018_0                                6.493751
# Liver-135_0                                4.035151
# Liver-015_0                                3.733124
#
#              PREDICT_original_sf_convexity_avg_2.5D  \
# ID
# Liver-149_0                                0.963279
# Liver-132_0                                0.924549
# Liver-018_0                                0.967914
# Liver-135_0                                0.944998
# Liver-015_0                                0.952526
#
#              PREDICT_original_sf_convexity_std_2.5D  \
# ID
# Liver-149_0                                0.022393
# Liver-132_0                                0.049767
# Liver-018_0                                0.015269
# Liver-135_0                                0.031507
# Liver-015_0                                0.027722
#
#              PREDICT_original_sf_cvar_avg_2.5D  \
# ID
# Liver-149_0                           0.021571
# Liver-132_0                           0.007751
# Liver-018_0                           0.035515
# Liver-135_0                           0.028765
# Liver-015_0                           0.016664
#
#              PREDICT_original_sf_cvar_std_2.5D  ...  \
# ID                                              ...
# Liver-149_0                           0.011780  ...
# Liver-132_0                           0.002992  ...
# Liver-018_0                           0.011933  ...
# Liver-135_0                           0.017286  ...
# Liver-015_0                           0.011443  ...
#
#              PREDICT_original_phasef_phasesym_median_WL3_N5  \
# ID
# Liver-149_0                                        0.000000
# Liver-132_0                                        0.000000
# Liver-018_0                                        0.015554
# Liver-135_0                                        0.000000
# Liver-015_0                                        0.000000
#
#              PREDICT_original_phasef_phasesym_std_WL3_N5  \
# ID
# Liver-149_0                                     0.104107
# Liver-132_0                                     0.100082
# Liver-018_0                                     0.152348
# Liver-135_0                                     0.108344
# Liver-015_0                                     0.078725
#
#              PREDICT_original_phasef_phasesym_skewness_WL3_N5  \
# ID
# Liver-149_0                                          2.756906
# Liver-132_0                                          3.289330
# Liver-018_0                                          1.301602
# Liver-135_0                                          1.929157
# Liver-015_0                                          3.747019
#
#              PREDICT_original_phasef_phasesym_kurtosis_WL3_N5  \
# ID
# Liver-149_0                                          8.453818
# Liver-132_0                                         11.458823
# Liver-018_0                                          0.810392
# Liver-135_0                                          3.090863
# Liver-015_0                                         15.215261
#
#              PREDICT_original_phasef_phasesym_peak_WL3_N5  \
# ID
# Liver-149_0                                           0.0
# Liver-132_0                                           0.0
# Liver-018_0                                           0.0
# Liver-135_0                                           0.0
# Liver-015_0                                           0.0
#
#              PREDICT_original_phasef_phasesym_peak_position_WL3_N5  \
# ID
# Liver-149_0                                                  0
# Liver-132_0                                                  0
# Liver-018_0                                                  0
# Liver-135_0                                                  0
# Liver-015_0                                                  0
#
#              PREDICT_original_phasef_phasesym_range_WL3_N5  \
# ID
# Liver-149_0                                       0.409805
# Liver-132_0                                       0.412003
# Liver-018_0                                       0.526233
# Liver-135_0                                       0.391573
# Liver-015_0                                       0.332604
#
#              PREDICT_original_phasef_phasesym_energy_WL3_N5  \
# ID
# Liver-149_0                                      222.558113
# Liver-132_0                                     2198.965478
# Liver-018_0                                      678.343564
# Liver-135_0                                     1168.726859
# Liver-015_0                                     1306.631943
#
#              PREDICT_original_phasef_phasesym_quartile_range_WL3_N5  \
# ID
# Liver-149_0                                           0.042636
# Liver-132_0                                           0.000000
# Liver-018_0                                           0.211135
# Liver-135_0                                           0.088960
# Liver-015_0                                           0.000000
#
#              PREDICT_original_phasef_phasesym_entropy_WL3_N5
# ID
# Liver-149_0                                        11.809102
# Liver-132_0                                        14.737962
# Liver-018_0                                        12.903202
# Liver-135_0                                        14.316269
# Liver-015_0                                        14.384808
#
# [5 rows x 493 columns]

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Delete features with more than 50% zeros

# %%
def delete_zeros(X_dataset):
  for column in X_dataset.columns:
    # Count amount of zeros in each column
    num_zeros = X_dataset[column].isin([0]).sum()

    # Calculate percentage of zeros in each column
    percentage_zeros = (num_zeros / len(X_dataset.index)) * 100

    # Check if there are more than 50% zeros in a column
    if percentage_zeros > 50:
        # Delete the column
        X_dataset.drop(column, axis=1, inplace=True)

  # Print the data shape before and after deleting features with >50% zeros
  print(f'The data shape after deleting features with >50% zeros: {X_dataset.shape}')
  return X_dataset


## STUKJE CODE OM TE CHECKEN HOEVEEL NULLEN ER NA VERWIJDERING NOG ZIJN
X_dataset = delete_zeros(X_train)
total_num_zeros = 0
for column in X_dataset.columns:
  num_zeros = X_dataset[column].isin([0]).sum()
  print(f"Number of zeros in {column}: {num_zeros}")
  total_num_zeros += num_zeros
print(f"Total number of zeros in the dataset: {total_num_zeros}")
# Out:
# The data shape after deleting features with >50% zeros: (148, 469)
# Number of zeros in PREDICT_original_sf_compactness_avg_2.5D: 0
# Number of zeros in PREDICT_original_sf_compactness_std_2.5D: 0
# Number of zeros in PREDICT_original_sf_rad_dist_avg_2.5D: 0
# Number of zeros in PREDICT_original_sf_rad_dist_std_2.5D: 0
# Number of zeros in PREDICT_original_sf_roughness_avg_2.5D: 0
# Number of zeros in PREDICT_original_sf_roughness_std_2.5D: 0
# Number of zeros in PREDICT_original_sf_convexity_avg_2.5D: 0
# Number of zeros in PREDICT_original_sf_convexity_std_2.5D: 0
# Number of zeros in PREDICT_original_sf_cvar_avg_2.5D: 0
# Number of zeros in PREDICT_original_sf_cvar_std_2.5D: 0
# Number of zeros in PREDICT_original_sf_prax_avg_2.5D: 0
# Number of zeros in PREDICT_original_sf_prax_std_2.5D: 0
# Number of zeros in PREDICT_original_sf_evar_avg_2.5D: 0
# Number of zeros in PREDICT_original_sf_evar_std_2.5D: 0
# Number of zeros in PREDICT_original_sf_solidity_avg_2.5D: 0
# Number of zeros in PREDICT_original_sf_solidity_std_2.5D: 0
# Number of zeros in PREDICT_original_sf_area_avg_2.5D: 0
# Number of zeros in PREDICT_original_sf_area_max_2.5D: 0
# Number of zeros in PREDICT_original_sf_area_min_2.5D: 0
# Number of zeros in PREDICT_original_sf_area_std_2.5D: 0
# Number of zeros in PREDICT_original_sf_volume_2.5D: 0
# Number of zeros in PREDICT_original_of_theta_x: 0
# Number of zeros in PREDICT_original_of_theta_y: 0
# Number of zeros in PREDICT_original_of_theta_z: 0
# Number of zeros in PREDICT_original_hf_min: 0
# Number of zeros in PREDICT_original_hf_max: 0
# Number of zeros in PREDICT_original_hf_mean: 0
# Number of zeros in PREDICT_original_hf_median: 0
# Number of zeros in PREDICT_original_hf_std: 0
# Number of zeros in PREDICT_original_hf_skewness: 0
# Number of zeros in PREDICT_original_hf_kurtosis: 0
# Number of zeros in PREDICT_original_hf_peak: 0
# Number of zeros in PREDICT_original_hf_peak_position: 0
# Number of zeros in PREDICT_original_hf_range: 0
# Number of zeros in PREDICT_original_hf_energy: 0
# Number of zeros in PREDICT_original_hf_quartile_range: 0
# Number of zeros in PREDICT_original_hf_entropy: 0
# Number of zeros in PREDICT_original_logf_min_sigma1: 0
# Number of zeros in PREDICT_original_logf_max_sigma1: 0
# Number of zeros in PREDICT_original_logf_mean_sigma1: 0
# Number of zeros in PREDICT_original_logf_median_sigma1: 0
# Number of zeros in PREDICT_original_logf_std_sigma1: 0
# Number of zeros in PREDICT_original_logf_skewness_sigma1: 0
# Number of zeros in PREDICT_original_logf_kurtosis_sigma1: 0
# Number of zeros in PREDICT_original_logf_peak_sigma1: 0
# Number of zeros in PREDICT_original_logf_peak_position_sigma1: 0
# Number of zeros in PREDICT_original_logf_range_sigma1: 0
# Number of zeros in PREDICT_original_logf_energy_sigma1: 0
# Number of zeros in PREDICT_original_logf_quartile_range_sigma1: 0
# Number of zeros in PREDICT_original_logf_entropy_sigma1: 0
# Number of zeros in PREDICT_original_logf_min_sigma5: 0
# Number of zeros in PREDICT_original_logf_max_sigma5: 0
# Number of zeros in PREDICT_original_logf_mean_sigma5: 0
# Number of zeros in PREDICT_original_logf_median_sigma5: 0
# Number of zeros in PREDICT_original_logf_std_sigma5: 0
# Number of zeros in PREDICT_original_logf_skewness_sigma5: 0
# Number of zeros in PREDICT_original_logf_kurtosis_sigma5: 0
# Number of zeros in PREDICT_original_logf_peak_sigma5: 0
# Number of zeros in PREDICT_original_logf_peak_position_sigma5: 0
# Number of zeros in PREDICT_original_logf_range_sigma5: 0
# Number of zeros in PREDICT_original_logf_energy_sigma5: 0
# Number of zeros in PREDICT_original_logf_quartile_range_sigma5: 0
# Number of zeros in PREDICT_original_logf_entropy_sigma5: 0
# Number of zeros in PREDICT_original_logf_min_sigma10: 0
# Number of zeros in PREDICT_original_logf_max_sigma10: 0
# Number of zeros in PREDICT_original_logf_mean_sigma10: 0
# Number of zeros in PREDICT_original_logf_median_sigma10: 0
# Number of zeros in PREDICT_original_logf_std_sigma10: 0
# Number of zeros in PREDICT_original_logf_skewness_sigma10: 0
# Number of zeros in PREDICT_original_logf_kurtosis_sigma10: 0
# Number of zeros in PREDICT_original_logf_peak_sigma10: 0
# Number of zeros in PREDICT_original_logf_peak_position_sigma10: 0
# Number of zeros in PREDICT_original_logf_range_sigma10: 0
# Number of zeros in PREDICT_original_logf_energy_sigma10: 0
# Number of zeros in PREDICT_original_logf_quartile_range_sigma10: 0
# Number of zeros in PREDICT_original_logf_entropy_sigma10: 0
# Number of zeros in PREDICT_original_tf_LBP_max_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_mean_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_median_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_std_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_skewness_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_kurtosis_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_peak_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_peak_position_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_range_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_energy_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_quartile_range_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_entropy_R3_P12: 0
# Number of zeros in PREDICT_original_tf_LBP_max_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_mean_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_median_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_std_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_skewness_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_kurtosis_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_peak_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_peak_position_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_range_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_energy_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_quartile_range_R8_P24: 33
# Number of zeros in PREDICT_original_tf_LBP_entropy_R8_P24: 0
# Number of zeros in PREDICT_original_tf_LBP_max_R15_P36: 0
# Number of zeros in PREDICT_original_tf_LBP_mean_R15_P36: 0
# Number of zeros in PREDICT_original_tf_LBP_median_R15_P36: 0
# Number of zeros in PREDICT_original_tf_LBP_std_R15_P36: 0
# Number of zeros in PREDICT_original_tf_LBP_skewness_R15_P36: 0
# Number of zeros in PREDICT_original_tf_LBP_kurtosis_R15_P36: 0
# Number of zeros in PREDICT_original_tf_LBP_peak_R15_P36: 0
# Number of zeros in PREDICT_original_tf_LBP_peak_position_R15_P36: 0
# Number of zeros in PREDICT_original_tf_LBP_range_R15_P36: 0
# Number of zeros in PREDICT_original_tf_LBP_energy_R15_P36: 0
# Number of zeros in PREDICT_original_tf_LBP_entropy_R15_P36: 0
# Number of zeros in PREDICT_original_tf_GLCM_contrastd1.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_contrastd1.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_contrastd1.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_contrastd1.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_contrastd3.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_contrastd3.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_contrastd3.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_contrastd3.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_dissimilarityd1.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_dissimilarityd1.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_dissimilarityd1.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_dissimilarityd1.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_dissimilarityd3.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_dissimilarityd3.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_dissimilarityd3.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_dissimilarityd3.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_homogeneityd1.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_homogeneityd1.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_homogeneityd1.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_homogeneityd1.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_homogeneityd3.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_homogeneityd3.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_homogeneityd3.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_homogeneityd3.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_ASMd1.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_ASMd1.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_ASMd1.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_ASMd1.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_ASMd3.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_ASMd3.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_ASMd3.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_ASMd3.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_energyd1.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_energyd1.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_energyd1.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_energyd1.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_energyd3.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_energyd3.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_energyd3.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_energyd3.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_correlationd1.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_correlationd1.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_correlationd1.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_correlationd1.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCM_correlationd3.0A0.0: 0
# Number of zeros in PREDICT_original_tf_GLCM_correlationd3.0A0.79: 0
# Number of zeros in PREDICT_original_tf_GLCM_correlationd3.0A1.57: 0
# Number of zeros in PREDICT_original_tf_GLCM_correlationd3.0A2.36: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd1.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd1.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd1.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd1.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd1.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd1.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd1.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd1.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd3.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd3.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd3.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd3.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd3.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd3.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd3.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_contrastd3.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd1.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd1.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd1.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd1.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd1.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd1.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd1.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd1.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd3.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd3.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd3.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd3.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd3.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd3.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd3.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_dissimilarityd3.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd1.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd1.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd1.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd1.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd1.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd1.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd3.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd3.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd3.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd3.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd3.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd3.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd3.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_homogeneityd3.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd1.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd1.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd1.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd1.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd1.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd1.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd1.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd1.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd3.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd3.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd3.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd3.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd3.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd3.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd3.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_ASMd3.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd1.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd1.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd1.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd1.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd1.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd1.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd1.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd1.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd3.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd3.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd3.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd3.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd3.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd3.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd3.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_energyd3.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd1.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd1.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd1.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd1.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd1.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd1.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd1.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd1.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd3.0A0.0mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd3.0A0.0std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd3.0A0.79mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd3.0A0.79std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd3.0A1.57mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd3.0A1.57std: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd3.0A2.36mean: 0
# Number of zeros in PREDICT_original_tf_GLCMMS_correlationd3.0A2.36std: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.05_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.05_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.05_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.05_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.2_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.2_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.2_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.2_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.5_A0.0: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.5_A0.79: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.5_A1.57: 0
# Number of zeros in PREDICT_original_tf_Gabor_min_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_max_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_mean_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_median_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_std_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_skewness_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_kurtosis_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_peak_position_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_range_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_energy_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_quartile_range_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_tf_Gabor_entropy_F0.5_A2.36: 0
# Number of zeros in PREDICT_original_vf_Frangi_full_max_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_full_mean_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_full_std_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_full_skewness_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_full_kurtosis_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_full_range_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_full_energy_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_full_quartile_range_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_full_entropy_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_edge_max_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_edge_mean_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_edge_std_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_edge_skewness_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_edge_kurtosis_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_edge_range_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_edge_energy_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_edge_quartile_range_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_edge_entropy_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_inner_max_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_inner_mean_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_inner_std_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_inner_skewness_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_inner_kurtosis_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_inner_range_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_inner_energy_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_inner_quartile_range_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_vf_Frangi_inner_entropy_SR(1.0, 10.0)_SS2.0: 0
# Number of zeros in PREDICT_original_phasef_monogenic_min_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_monogenic_max_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_monogenic_mean_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_monogenic_median_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_monogenic_std_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_monogenic_skewness_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_monogenic_kurtosis_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_monogenic_peak_WL3_N5: 3
# Number of zeros in PREDICT_original_phasef_monogenic_peak_position_WL3_N5: 3
# Number of zeros in PREDICT_original_phasef_monogenic_range_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_monogenic_energy_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_monogenic_quartile_range_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_monogenic_entropy_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasecong_max_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasecong_mean_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasecong_std_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasecong_skewness_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasecong_kurtosis_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasecong_range_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasecong_energy_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasecong_quartile_range_WL3_N5: 27
# Number of zeros in PREDICT_original_phasef_phasecong_entropy_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasesym_max_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasesym_mean_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasesym_std_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasesym_skewness_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasesym_kurtosis_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasesym_range_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasesym_energy_WL3_N5: 0
# Number of zeros in PREDICT_original_phasef_phasesym_quartile_range_WL3_N5: 47
# Number of zeros in PREDICT_original_phasef_phasesym_entropy_WL3_N5: 0
# Total number of zeros in the dataset: 113

# %% [markdown]
# ### Outliers

# %%
def define_outliers(X_dataset):
    outliers_total = 0
    for column in X_dataset.columns:
        sorted_feature = np.sort(X_dataset[column])  # Sort the values of the column
        Q1 = np.percentile(sorted_feature, 25)
        Q3 = np.percentile(sorted_feature, 75)
        IQR = Q3 - Q1
        lower_bound = Q1 - (1.5 * IQR)
        upper_bound = Q3 + (1.5 * IQR)
        outliers_total_column = ((sorted_feature < lower_bound) | (sorted_feature > upper_bound)).sum()
        outliers_total += outliers_total_column
    return outliers_total

# %% [markdown]
# ### RobustScaling

# %%
# Function to scale the dataset using RobustScaler because there are outliers and the features are not normally distributed
def scaling(X_dataset):
  scaler = RobustScaler(quantile_range=(0.1, 0.9)).fit(X_dataset) # first and last 10% of samples are seen as outliers
  scaler.fit(X_dataset)
  X_dataset_scaled = scaler.transform(X_dataset)
  X_dataset_scaled = pd.DataFrame(data=X_dataset_scaled, columns=X_dataset.columns)
  return X_dataset_scaled

# %% [markdown]
# ### Remove zero variance

# %%
def zero_variance(X_dataset_scaled):
  # Remove features with zero variance
  vt = VarianceThreshold(threshold=0.0)
  X_dataset_var = vt.fit_transform(X_dataset_scaled)
  # Select the right columns from X_dataset_scaled
  selected_columns = X_dataset_scaled.columns[vt.get_support()]

  # Create a dataframe for X_dataset_var with only the selected columns
  X_dataset_var = pd.DataFrame(X_dataset_var, columns=selected_columns)
  print(f'The data shape before removing zero variance: {X_dataset_scaled.shape} and after: {X_dataset_var.shape}')
  return X_dataset_var

# %% [markdown]
# ### ANOVA test

# %%
# Function to perform ANOVA test. ANOVA feature selection for numeric input and categorical output
def anova_analysis(X_dataset_var, Y_dataset):
  # Define feature selection
  fs = SelectKBest(score_func=f_classif, k='all')

  # Apply feature selection
  X_dataset_anova = fs.fit_transform(X_dataset_var, Y_dataset)
  X_dataset_anova = pd.DataFrame(data=X_dataset_anova, columns=X_dataset_var.columns)
  feature_scores = list(zip(fs.pvalues_, X_dataset_anova.columns))

  # Select the features with p<0.05, because only than benign is significantly different from malignant
  selected_features = [feature[1] for feature in feature_scores if feature[0] < 0.05]

  # Create a dataframe for X_dataset_anova with only the selected features
  X_dataset_anova = X_dataset_anova[selected_features]
  print(f'The data shape before ANOVA: {X_dataset_var.shape} and after ANOVA: {X_dataset_anova.shape}')
  return X_dataset_anova

# %% [markdown]
# ## RFECV

# %%
def function_calc_RFECV(X_dataset_anova, Y_dataset): # x_train_anova must be used as an argument here.

    label_encoder = LabelEncoder()
    Y_encoded = label_encoder.fit_transform(Y_dataset)

    clf = SVC(kernel='linear',random_state=0)

    # Initializing cross-validation
    cv = StratifiedKFold(n_splits=5)
    min_features_to_select = 1
    rfecv = RFECV(estimator=clf,
                  step=5,
                  cv=cv,
                  scoring='roc_auc',
                  min_features_to_select=min_features_to_select
                  )
    rfecv.fit(X_dataset_anova, Y_encoded)
    print(f'Optimal number of features: {rfecv.n_features_}')

    X_rfecv = rfecv.transform(X_dataset_anova)

    # Get the selected feature indices
    selected_features_indices = rfecv.get_support()

    X_dataset_anova = pd.DataFrame(X_dataset_anova)

    # Get the names of the selected features
    selected_column_names = X_dataset_anova.columns[selected_features_indices]

    print(f'The data shape before RFECV: {X_dataset_anova.shape} and after RFECV: {X_rfecv.shape}')
    return X_rfecv, selected_column_names

# %% [markdown]
# ## Classifiers

# %% [markdown]
# ### Create functions which are used in the classifiers

# %%
# Function to initialize label encoder
def label_encoder(Y_dataset):
  label_encoder = LabelEncoder()

  # Apply label encoder on Y_train to transform categorical input to numeric input. Malignant = 1, benigne = 0
  Y_dataset_encoded = label_encoder.fit_transform(Y_dataset)

  # Define the coded classes
  print("Coded classes:", label_encoder.classes_)
  return Y_dataset_encoded

# %% [markdown]
# ### K-NN

# %%
def KNN(X_dataset_rfecv, Y_dataset_encoded):
  # Define a parameter grid for RandomizedSearchCV
  parameter_grid = {'n_neighbors': list(range(10, 40)),
                    'weights': ['uniform','distance'],
                    'p': list(range(1, 10)),
                    'algorithm': ['ball_tree','kd_tree','brute','auto'],
                    'leaf_size': [30]
                    }
  # Creating way of scoring
  f2_scorer = make_scorer(fbeta_score, beta=2)
  # Initializing cross-validation
  cv = StratifiedKFold(n_splits=5)

  # Create a RandomizedSearchCV and apply it to the dataset with crossvalidation
  rscv_knn = RandomizedSearchCV(KNeighborsClassifier(), param_distributions=parameter_grid, n_iter=40, cv=cv, random_state=0, scoring=f2_scorer)

  # Fit the classifier
  rscv_knn.fit(X_dataset_rfecv, Y_dataset_encoded)

  # Extract the best parameters and show the F2-score
  print('Best parameters found for KNN-classifier:', rscv_knn.best_params_)
  print('Best F2-score found for KNN-classifier:', rscv_knn.best_score_)

  # Fit the classifier with the best parameters on the dataset
  knn_classifier = rscv_knn.best_estimator_
  knn_classifier.fit(X_dataset_rfecv, Y_dataset_encoded)
  return rscv_knn, knn_classifier

# %% [markdown]
# ### Decision Tree Classifier

# %%
def DTC(X_dataset_rfecv, Y_dataset_encoded):
  # Define a parameter grid for RandomizedSearchCV
  parameter_grid = {"max_depth": np.arange(3,10,1),
                    "min_samples_split": np.arange(10,30,2),
                    'min_samples_leaf': np.arange(10,30,2),
                    "criterion": ['gini', 'entropy', 'log_loss'],
                    "splitter": ['best'],
                    }

  # Creating way of scoring
  f2_scorer = make_scorer(fbeta_score, beta=2)
  # Initializing cross-validation
  cv = StratifiedKFold(n_splits=5)

  # Create a RandomizedSearchCV and apply it to the dataset with crossvalidation
  rscv_dtc = RandomizedSearchCV(tree.DecisionTreeClassifier(), param_distributions=parameter_grid, refit=True, verbose=1, scoring=f2_scorer, cv=cv, random_state=0, n_iter=30)

  # Fit the classifier
  rscv_dtc.fit(X_dataset_rfecv, Y_dataset_encoded)

  # Extract the best parameters and show the F2-score
  print('Best parameters found for decision tree classifier:', rscv_dtc.best_params_)
  print('Best F2-score found for decision tree classifier:', rscv_dtc.best_score_)

  # Fit the classifier with the best parameters on the dataset
  dtc_classifier = rscv_dtc.best_estimator_
  dtc_classifier.fit(X_dataset_rfecv, Y_dataset_encoded)
  return rscv_dtc, dtc_classifier

# %% [markdown]
# ## RandomForest Classifier

# %%
def RFC(X_dataset_rfecv, Y_dataset_encoded):
  parameter_grid = {'n_estimators': np.arange(50, 150, 25),
                  'max_depth': np.arange(3, 7),
                  'max_leaf_nodes': np.arange(2, 8),
                  'min_samples_split': np.arange(2, 5),
                  'min_samples_leaf': np.arange(1, 4)
                 }

  # Creating way of scoring
  f2_scorer = make_scorer(fbeta_score, beta=2)
  # Initializing cross-validation
  cv = StratifiedKFold(n_splits=5)

  # Create a RandomizedSearchCV and apply it to the dataset with crossvalidation
  rscv_rf = RandomizedSearchCV(RandomForestClassifier(), param_distributions=parameter_grid, cv=cv, n_iter=20, scoring=f2_scorer, random_state=0)

  # Fit the classifier
  rscv_rf.fit(X_dataset_rfecv, Y_dataset_encoded)

  # Extract the best parameters and show the F2-score
  print('Best parameters found for random forest classifier:', rscv_rf.best_params_)
  print('Best F2-score found for random forest classifier:', rscv_rf.best_score_)

  # Fit the classifier with the best parameters on the dataset
  rf_classifier = rscv_rf.best_estimator_
  rf_classifier.fit(X_dataset_rfecv, Y_dataset_encoded)
  return rscv_rf, rf_classifier

# %% [markdown]
# ### SVM

# %%
def SVM(X_dataset_rfecv, Y_dataset_encoded):
  # Define a parameter grid for RandomizedSearchCV
  parameter_grid = {'C': np.logspace(-3, 1, 5),  # Probeer kleinere waarden voor C
                  'gamma': np.logspace(-3, 0, 4),  # Probeer kleinere waarden voor gamma
                  'kernel': ['linear']  # Gebruik een lineaire kernel
                  }

  # Creating way of scoring
  f2_scorer = make_scorer(fbeta_score, beta=2)
  # Initializing cross-validation
  cv = StratifiedKFold(n_splits=5)

  # Create a RandomizedSearchCV and apply it to the dataset with crossvalidation
  rscv_svm = RandomizedSearchCV(SVC(), param_distributions=parameter_grid, n_iter=20, cv=cv, scoring=f2_scorer, random_state=0)

  # Fit the classifier
  rscv_svm.fit(X_dataset_rfecv, Y_dataset_encoded)

  # Extract the best parameters and show the F2-score
  print('Best parameters found for SVM classifier:', rscv_svm.best_params_)
  print('Best F2-score found for SVM classifier:', rscv_svm.best_score_)

  # Fit the classifier with the best parameters on the dataset
  svm_classifier = rscv_svm.best_estimator_
  svm_classifier.fit(X_train_rfecv, Y_train_encoded)
  return rscv_svm, svm_classifier

# %% [markdown]
# ### Learning curves

# %%
def plot_learning_curve(estimator, title, X, Y, cv=None, train_sizes=np.linspace(.1, 1.0, 10)):
    """
    Plots a learning curve.
    """
    plt.figure(figsize=(10, 6))
    plt.title(title)
    plt.xlabel("Number of training examples")
    plt.ylabel("F2-score")

    # Creating way of scoring
    f2_scorer = make_scorer(fbeta_score, beta=2)
    # Initializing cross-validation
    cv = StratifiedKFold(n_splits=5)

    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, Y, cv=cv, scoring=f2_scorer, train_sizes=train_sizes, n_jobs=-1, random_state=0)

    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)

    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training F2-score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation F2-score")

    plt.legend(loc="best")
    return plt

# %% [markdown]
# ## Ensembling

# %%
def voting(X_dataset_rfecv, Y_dataset):
  voting = VotingClassifier(estimators=[
  ('knn', KNN_classifier),
  ('dtc', DTC_classifier),
  ('rf', RF_classifier),
  ('svm', SVM_classifier)],
  voting='hard')

  # Train de voting classifier
  voting.fit(X_dataset_rfecv, Y_dataset)
  return voting

# %% [markdown]
# ### Calculating metrics
# IS DIt OUTER CROSS VALIDATIE??

# %%
def metrics(classifiers, X_dataset_rfecv, Y_dataset):
  results = {'Metrics': ['Accuracy', 'Precision', 'Recall', 'F2 score', 'ROC AUC']}

  # Creating way of scoring
  f2_scorer = make_scorer(fbeta_score, beta=2)
  # Initializing cross-validation
  cv = StratifiedKFold(n_splits=5)

  # Loop through best fitted classifiers, perform cross_validation and calculate the mean scores
  for clf in classifiers:
    accuracy = cross_val_score(clf, X_dataset_rfecv, Y_dataset, cv=cv, scoring='accuracy').mean()
    precision = cross_val_score(clf, X_dataset_rfecv, Y_dataset, cv=cv, scoring='precision_macro').mean()
    recall = cross_val_score(clf, X_dataset_rfecv, Y_dataset, cv=cv, scoring='recall_macro').mean()
    f2_score = cross_val_score(clf, X_dataset_rfecv, Y_dataset, cv=cv, scoring=f2_scorer).mean()
    if clf != voting_classifier:  # Check if current classifier is not voting_classifier, because roc_auc is not possible to define using a 'hard' voting classifier
        roc_auc = cross_val_score(clf, X_dataset_rfecv, Y_dataset, cv=cv, scoring='roc_auc').mean()
    else:
        roc_auc = None  # Set roc_auc to None for voting_classifier

    # Add classifier names to the table
    clf_name = clf.__class__.__name__
    results[clf_name] = [accuracy, precision, recall, f2_score, roc_auc]

  # Create a dataframe of the results
  results_df = pd.DataFrame(results)

  # Transpose dataframe
  results_df.set_index('Metrics', inplace=True)
  results_df = results_df.T

  # Print table
  print(tabulate(results_df, headers='keys', tablefmt='pretty'))
  return None

# %% [markdown]
# ### ROC curve

# %%
def plot_roc_curve(y_pred, y_truth):
    '''
    Plot an ROC curve.
    '''

    # Compute ROC curve and ROC area for each class
    fpr, tpr, _ = roc_curve(y_truth, y_pred)
    roc_auc = auc(fpr, tpr)

    # Plot the ROC curve
    plt.figure()
    lw = 2
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc="lower right")
    plt.show()
    return None

def plot_roc_curve_multi(y_preds, y_truth, labels):
    '''
    Plot ROC curves for multiple classifiers in the same plot.
    '''

    # Plot the ROC curves for each classifier
    plt.figure()
    lw = 2
    for i in range(len(y_preds)):
        fpr, tpr, _ = roc_curve(y_truth, y_preds[i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=lw, label=f'{labels[i]} (area = {roc_auc:.2f})')

    # Plot the diagonal dashed line representing random guessing
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')

    # Set plot labels and title
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curves for multiple classifiers')
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ### Confusion matrix

# %%
def determine_confusion_matrix(y_truth, y_pred):
    cm = confusion_matrix(y_truth, y_pred)
    cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Benigne', 'Malignant'])
    cm_display.plot()
    plt.title('Confusion matrix')
    plt.show()
    return None

def determine_confusion_matrix_multi(classifiers, y_truth, y_preds):
    '''
    Determine and display the confusion matrix for multiple classifiers.
    '''
    for name, y_pred in zip(classifiers.keys(), y_preds):
        # Determine confusion matrix
        cm = confusion_matrix(y_truth, y_pred)
        cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Benigne', 'Malignant'])

        # Plot confusion matrix
        plt.figure()
        cm_display.plot()
        plt.title(f'Confusion matrix for {name}')
        plt.show()

# %% [markdown]
# ## Performing functions on training set

# %%
# Pre-processing
X_train = delete_zeros(X_train)
outliers_total = define_outliers(X_train)
print(f'In total there are {outliers_total} outliers')
X_train_scaled = scaling(X_train)
X_train_var = zero_variance(X_train_scaled)
X_train_anova = anova_analysis(X_train_var, Y_train)
X_train_rfecv, feature_names = function_calc_RFECV(X_train_anova,Y_train)
Y_train_encoded = label_encoder(Y_train)

# Classifiers
RSCV_KNN, KNN_classifier = KNN(X_train_rfecv, Y_train_encoded)
RSCV_DTC, DTC_classifier = DTC(X_train_rfecv, Y_train_encoded)
RSCV_RF, RF_classifier = RFC(X_train_rfecv, Y_train_encoded)
RSCV_SVM, SVM_classifier = SVM(X_train_rfecv, Y_train_encoded)
voting_classifier = voting(X_train_rfecv, Y_train_encoded)

# Learning curves
# Create a list with all the classifiers
classifiers = {'Decision tree classifier': DTC_classifier, 'K-NN classifier': KNN_classifier, 'Random forest classifier': RF_classifier, 'SVM classifier': SVM_classifier, 'Ensembling through voting': voting_classifier}

# Initializing cross-validation
cv = StratifiedKFold(n_splits=5)
# Plot the learning curve for each classifier
for name, clf in classifiers.items():
  title = f"Learning Curves ({name})"
  plot_learning_curve(clf, title, X_train_rfecv, Y_train_encoded, cv=cv)
  plt.show()

# Create a table with all the metrics of the classifiers performed on the training set
metrics([KNN_classifier, DTC_classifier, RF_classifier, SVM_classifier, voting_classifier], X_train_rfecv, Y_train_encoded)
# Out:
# The data shape after deleting features with >50% zeros: (148, 469)
# In total there are 2859 outliers
# The data shape before removing zero variance: (148, 469) and after: (148, 459)
# The data shape before ANOVA: (148, 459) and after ANOVA: (148, 61)
# Optimal number of features: 16
# The data shape before RFECV: (148, 61) and after RFECV: (148, 16)
# Coded classes: ['benign' 'malignant']
# Best parameters found for KNN-classifier: {'weights': 'uniform', 'p': 1, 'n_neighbors': 17, 'leaf_size': 30, 'algorithm': 'kd_tree'}
# Best F2-score found for KNN-classifier: 0.6959828933513144
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best parameters found for decision tree classifier: {'splitter': 'best', 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_depth': 5, 'criterion': 'entropy'}
# Best F2-score found for decision tree classifier: 0.6785768910790587
# Best parameters found for random forest classifier: {'n_estimators': 125, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_leaf_nodes': 6, 'max_depth': 4}
# Best F2-score found for random forest classifier: 0.7584810624382416
# Best parameters found for SVM classifier: {'kernel': 'linear', 'gamma': 0.001, 'C': 1.0}
# Best F2-score found for SVM classifier: 0.7158170703592477
# +------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                        |      Accuracy      |     Precision      |       Recall       |      F2 score      |      ROC AUC       |
# +------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |  KNeighborsClassifier  | 0.6627586206896552 | 0.6642897543632837 | 0.6619047619047619 | 0.6959828933513144 | 0.7308888888888889 |
# | DecisionTreeClassifier | 0.6418390804597701 | 0.6525939007672753 | 0.6409523809523809 | 0.6785768910790587 | 0.6344761904761904 |
# | RandomForestClassifier | 0.7165517241379311 | 0.6985596674567264 | 0.6833333333333332 | 0.7219068255687975 | 0.7454603174603174 |
# |          SVC           | 0.7096551724137932 | 0.7112812432665374 | 0.7095238095238094 | 0.7158170703592477 | 0.7967619047619048 |
# |    VotingClassifier    | 0.7239080459770115 | 0.699681103210515  | 0.6966666666666667 | 0.7002246081698137 |        nan         |
# +------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# ## Performing functions on test set

# %%
X_test_scaled = scaling(X_test)
Y_test_encoded = label_encoder(Y_test)

# Select the right columns based on the selected columns in the pre-processing of the train set
X_test_useful_features = X_test_scaled[feature_names]

# calculating metrics for all classifiers on testset
clfs = [KNN_classifier, DTC_classifier, RF_classifier, SVM_classifier, voting_classifier]
metrics(clfs, X_test_useful_features, Y_test_encoded)

# plotting ROC curve for all classifiers on testset
classifiers = {'Decision tree classifier': DTC_classifier, 'K-NN classifier': KNN_classifier, 'Random forest classifier': RF_classifier, 'SVM classifier': SVM_classifier, 'Ensembling through voting': voting_classifier}

Y_preds = []
for clf in clfs:
  Y_pred = clf.predict(X_test_useful_features)
  Y_preds.append(Y_pred)

labels = ['KNN_classifier', 'DTC_classifier', 'RF_classifier', 'SVM_classifier', 'voting_classifier']
plot_roc_curve_multi(Y_preds, Y_test_encoded, labels)

# determine confusion matrices for all classifiers
determine_confusion_matrix_multi(classifiers, Y_test_encoded, Y_preds)



## DIT IS VOOR ALS WE HET TOCH ALLEEN OP VOTING WILLEN:
# # Create a table with all the metrics of the classifiers performed on the training set
# clf = [voting_classifier]
# metrics(clf, X_test_useful_features, Y_test_encoded)

# # ROC curve plotten
# Y_pred_voting = voting_classifier.predict(X_test_useful_features)
# plot_roc_curve(Y_pred_voting, Y_test_encoded)

# # Creating a confusion matrix
# determine_confusion_matrix(Y_test_encoded, Y_pred_voting)
# Out:
# Coded classes: ['benign' 'malignant']
# +------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                        |      Accuracy      |     Precision      |       Recall       |      F2 score      |      ROC AUC       |
# +------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |  KNeighborsClassifier  | 0.7642857142857143 | 0.8083333333333333 |       0.775        | 0.8137626262626263 |      0.79375       |
# | DecisionTreeClassifier | 0.6571428571428571 | 0.6766666666666665 | 0.5916666666666666 | 0.6315998329156225 | 0.6479166666666666 |
# | RandomForestClassifier | 0.7357142857142858 | 0.8033333333333333 |        0.75        | 0.7391806722689076 |        0.9         |
# |          SVC           | 0.6607142857142858 | 0.6716666666666666 | 0.6666666666666666 | 0.7196029847345636 | 0.6583333333333334 |
# |    VotingClassifier    | 0.7392857142857142 | 0.7766666666666666 |        0.75        | 0.7016806722689075 |        nan         |
# +------------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
